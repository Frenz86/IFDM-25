# %% [markdown]
# ## Openweather

# %%
#!pip install python-dotenv
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
api_key = os.getenv('API_KEY')

# %%
url = f"https://api.openweathermap.org/data/2.5/weather?lat=44.34&lon=10.99&appid={api_key}"

city_name = 'ravenna'

url2 =f"https://api.openweathermap.org/data/2.5/weather?q={city_name}&appid={api_key}"

# %%
import requests

response = requests.get(url2)
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'coord': {'lon': 11.4333, 'lat': 44.4667},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'base': 'stations',
#  'main': {'temp': 282.65,
#   'feels_like': 282.19,
#   'temp_min': 282.18,
#   'temp_max': 283.51,
#   'pressure': 1009,
#   'humidity': 71,
#   'sea_level': 1009,
#   'grnd_level': 993},
#  'visibility': 10000,
#  'wind': {'speed': 1.54, 'deg': 320},
#  'clouds': {'all': 40},
#  'dt': 1764163836,
#  'sys': {'type': 2,
#   'id': 2004497,
#   'country': 'IT',
#   'sunrise': 1764138287,
#   'sunset': 1764171526},
#  'timezone': 3600,
#  'id': 3181927,
#  'name': 'Bologna',
#  'cod': 200}

# %%
import requests

city = 'Bologna'

url = f'http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}'
result = requests.get(url)
json = result.json()
json
# Out:
# {'coord': {'lon': 11.4333, 'lat': 44.4667},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 282.32,
#   'feels_like': 280.94,
#   'temp_min': 282,
#   'temp_max': 282.62,
#   'pressure': 1008,
#   'humidity': 70,
#   'sea_level': 1008,
#   'grnd_level': 993},
#  'visibility': 10000,
#  'wind': {'speed': 2.57, 'deg': 300},
#  'clouds': {'all': 0},
#  'dt': 1764155409,
#  'sys': {'type': 2,
#   'id': 2004497,
#   'country': 'IT',
#   'sunrise': 1764138287,
#   'sunset': 1764171526},
#  'timezone': 3600,
#  'id': 3181927,
#  'name': 'Bologna',
#  'cod': 200}

# %%
print(result.content)
# Out:
# b'{"coord":{"lon":11.4333,"lat":44.4667},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}],"base":"stations","main":{"temp":282.32,"feels_like":280.94,"temp_min":282,"temp_max":282.62,"pressure":1008,"humidity":70,"sea_level":1008,"grnd_level":993},"visibility":10000,"wind":{"speed":2.57,"deg":300},"clouds":{"all":0},"dt":1764155409,"sys":{"type":2,"id":2004497,"country":"IT","sunrise":1764138287,"sunset":1764171526},"timezone":3600,"id":3181927,"name":"Bologna","cod":200}'

# %%
json['wind']['speed']
# Out:
# 2.57

# %% [markdown]
# ## With gradio

# %%
import os
import requests
import gradio as gr
from dotenv import load_dotenv
load_dotenv('.env')
api_key = os.getenv('API_KEY')

url = 'http://api.openweathermap.org/data/2.5/weather?q={}&appid={}'

# %%
def get_weather_info(city):
    result = requests.get(url.format(city, api_key))
    json_data = result.json()
    wind_speed = json_data['wind']['speed']
    return wind_speed

# %%
city_input = gr.components.Textbox(label="Inserire la città")
wind = gr.components.Textbox(label="Velocità del vento (m/s)")


interface = gr.Interface(fn=get_weather_info,
                         inputs=city_input,
                         outputs=[wind],
                         title="Informazioni Meteo IFOA",
                         description="Inserisci la città di interesse",
                         allow_flagging="never",
                         )

interface.launch()
# Out:
# c:\Users\danie\AppData\Local\Programs\Python\Python311\Lib\site-packages\gradio\interface.py:419: UserWarning: The `allow_flagging` parameter in `Interface` is deprecated.Use `flagging_mode` instead.
#   warnings.warn(
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
def get_weather_temp(city):
    result = requests.get(url.format(city, api_key))
    json_data = result.json()
    temp = json_data['main']['temp'] - 273.15
    return round(temp,1)

# %%
# input
city_input = gr.components.Textbox(label="Inserire la città")
# output
temp = gr.components.Textbox(label="Temperatura °C")


interface = gr.Interface(fn=get_weather_temp,
                         inputs=city_input,
                         outputs=[temp],
                         title="Informazioni Meteo IFOA",
                         description="Inserisci la città di interesse",
                         allow_flagging="never", #new version flagging_mode='never',
                         )

interface.launch()
# Out:
# c:\Users\danie\AppData\Local\Programs\Python\Python311\Lib\site-packages\gradio\interface.py:419: UserWarning: The `allow_flagging` parameter in `Interface` is deprecated.Use `flagging_mode` instead.
#   warnings.warn(
# * Running on local URL:  http://127.0.0.1:7870
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7870/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## With Gradio Complete

# %%
def get_weather_info(city):
    api_key = os.getenv('API_KEY')
    url = f'http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}'
    #result = requests.get(url.format(city, api_key))
    result = requests.get(url)
    json_data = result.json()
    wind_speed = json_data['wind']['speed']
    pressure = json_data['main']['pressure']
    humidity = json_data['main']['humidity']
    
    return wind_speed, pressure, humidity

# INPUT
city_input = gr.components.Textbox(label="Inserire la città")

# OUTPUT
wind = gr.components.Textbox(label="Velocità del vento (m/s)")
pressure = gr.components.Textbox(label="Pressione (hPa)")
humidity = gr.components.Textbox(label="Umidità (%)")

interface = gr.Interface(fn=get_weather_info,
                         inputs=city_input, # INPUT VARIABLE
                         outputs=[wind, pressure, humidity], # OUTPUT VARIABLE
                         title="Informazioni Meteo IFOA",
                         description="Inserisci la città di interesse",
                         allow_flagging="never",
                         )

interface.launch()
# Out:
# c:\Users\danie\AppData\Local\Programs\Python\Python311\Lib\site-packages\gradio\interface.py:419: UserWarning: The `allow_flagging` parameter in `Interface` is deprecated.Use `flagging_mode` instead.
#   warnings.warn(
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
